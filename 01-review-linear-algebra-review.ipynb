# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# %% [markdown]
# ### Visualizing the Linear Transformations
# This is for replicating 3Blue1Brown's YouTube animation.
#
# Some Other Good Resources for understanding Linear Transformations
# - [Exploring Linear Transformations with Python](https://notgnoshi.github.io/linear-transformations/)
# - [Visualizing 2D linear transformations](https://dododas.github.io/linear-algebra-with-python/posts/16-12-29-2d-transformations.html)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('XkY2DOUCWMU')

# %% [markdown]
# #### 1. Generate a Grid

# %%
color_palette = ['#BE0E18', '#DD6317', '#E8D471', '#239176', '#20333F']

color_palette = np.repeat(color_palette, 5)

xvals = np.linspace(-2, 2, 5)
yvals = np.linspace(-2, 2, 5)
xygrid = np.column_stack([[x, y] for x in xvals for y in yvals])

plt.style.use('ggplot')
plt.scatter(xygrid[0], xygrid[1], s = 100, c = color_palette)
plt.title('The Original Grid', fontsize=10)
plt.axis('equal')
plt.show()

# %% [markdown]
# #### Shear

# %%
a = np.array([[1,1],
              [0,1]])

# linear transformation
transformed = a@xygrid

plt.style.use('ggplot')
plt.scatter(transformed[0], transformed[1], s = 100, c = color_palette)
plt.title('Apply a Linear Transformation: Shear', fontsize=10)
plt.axis('equal')
plt.show()

# %% [markdown]
# #### Rotate

# %%
a = np.array([[0,-1],
              [1, 0]])

# linear transformation
transformed = a@xygrid

plt.style.use('ggplot')
plt.scatter(transformed[0], transformed[1], s = 100, c = color_palette)
plt.title('Apply a Linear Transformation: Shear', fontsize=10)
plt.axis('equal')
plt.show()
